# %%
import lightgbm as lgb
import numpy as np

# %% [markdown]
# ## Prototype 1: use `lightgbm.train` with a learning-to-rank objective

# %%
X_train = np.random.random(size=(100, 3))
y_train = np.random.randint(low=0, high=3, size=100)
group_train = [20] * 5

X_test = np.random.random(size=(50, 3))
y_test = np.random.randint(low=0, high=3, size=50)
group_test = [10] * 5

# %%
train_set = lgb.Dataset(X_train, label=y_train, group=group_train)
test_set = lgb.Dataset(X_test, label=y_test, group=group_test)

# %%
params = {
    'objective': 'rank_xendcg',
    'num_iterations': 5
}
    
gbm = lgb.train(
    params,
    train_set,
    valid_sets=[test_set]
)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 105
# [LightGBM] [Info] Number of data points in the train set: 100, number of used features: 3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
gbm.best_score
# Out:
# defaultdict(collections.OrderedDict,
#             {'valid_0': OrderedDict([('ndcg@1',
#                            np.float64(0.3333333333333333)),
#                           ('ndcg@2', np.float64(0.33333333333333337)),
#                           ('ndcg@3', np.float64(0.48243913572790253)),
#                           ('ndcg@4', np.float64(0.563339261997658)),
#                           ('ndcg@5', np.float64(0.5649721147346176))])})

# %% [markdown]
# ## Prototype 2. Pass additional parameters via ray

# %%
from ray import tune, train

# %%
def objective(x, a, b):  # Define an objective function.
    return a * (x**0.5) + b

def trainable(config):  # Pass a "config" dictionary into your trainable.
    for x in range(20):  # "Train" for 20 iterations and compute intermediate scores.
        score = objective(x, config["a"], config["b"])
        train.report({"score": score})  # Send the score to Tune.

space = {"a": tune.uniform(0, 1), "b": tune.uniform(0, 1)}
tuner = tune.Tuner(
    trainable, param_space=space, tune_config=tune.TuneConfig(num_samples=10)
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-21 16:09:51</td></tr>
# <tr><td>Running for: </td><td>00:00:07.90        </td></tr>
# <tr><td>Memory:      </td><td>6.6/8.0 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/8 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc            </th><th style="text-align: right;">         a</th><th style="text-align: right;">       b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   score</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_8d0b1_00000</td><td>TERMINATED</td><td>127.0.0.1:13696</td><td style="text-align: right;">0.00272812</td><td style="text-align: right;">0.801932</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00370598</td><td style="text-align: right;">0.813823</td></tr>
# <tr><td>trainable_8d0b1_00001</td><td>TERMINATED</td><td>127.0.0.1:13697</td><td style="text-align: right;">0.832212  </td><td style="text-align: right;">0.430026</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00292897</td><td style="text-align: right;">4.05755 </td></tr>
# <tr><td>trainable_8d0b1_00002</td><td>TERMINATED</td><td>127.0.0.1:13698</td><td style="text-align: right;">0.803056  </td><td style="text-align: right;">0.569794</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00418186</td><td style="text-align: right;">4.07023 </td></tr>
# <tr><td>trainable_8d0b1_00003</td><td>TERMINATED</td><td>127.0.0.1:13699</td><td style="text-align: right;">0.728951  </td><td style="text-align: right;">0.437756</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00290537</td><td style="text-align: right;">3.61518 </td></tr>
# <tr><td>trainable_8d0b1_00004</td><td>TERMINATED</td><td>127.0.0.1:13700</td><td style="text-align: right;">0.0364744 </td><td style="text-align: right;">0.560293</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00318837</td><td style="text-align: right;">0.719282</td></tr>
# <tr><td>trainable_8d0b1_00005</td><td>TERMINATED</td><td>127.0.0.1:13701</td><td style="text-align: right;">0.971483  </td><td style="text-align: right;">0.451571</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00352502</td><td style="text-align: right;">4.68617 </td></tr>
# <tr><td>trainable_8d0b1_00006</td><td>TERMINATED</td><td>127.0.0.1:13702</td><td style="text-align: right;">0.0730874 </td><td style="text-align: right;">0.296075</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00367713</td><td style="text-align: right;">0.614656</td></tr>
# <tr><td>trainable_8d0b1_00007</td><td>TERMINATED</td><td>127.0.0.1:13703</td><td style="text-align: right;">0.164792  </td><td style="text-align: right;">0.663394</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00300169</td><td style="text-align: right;">1.38171 </td></tr>
# <tr><td>trainable_8d0b1_00008</td><td>TERMINATED</td><td>127.0.0.1:13706</td><td style="text-align: right;">0.550588  </td><td style="text-align: right;">0.962744</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00144863</td><td style="text-align: right;">3.3627  </td></tr>
# <tr><td>trainable_8d0b1_00009</td><td>TERMINATED</td><td>127.0.0.1:13707</td><td style="text-align: right;">0.747     </td><td style="text-align: right;">0.802802</td><td style="text-align: right;">    20</td><td style="text-align: right;">      0.00141406</td><td style="text-align: right;">4.0589  </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-07-21 16:09:51,234	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/hongsupshin/ray_results/trainable_2024-07-21_16-09-43' in 0.0130s.
# 2024-07-21 16:09:51,240	INFO tune.py:1041 -- Total run time: 7.92 seconds (7.89 seconds for the tuning loop).

# %%
results.get_best_result(metric='score', mode='max')
# Out:
# Result(
#   metrics={'score': 4.686165492417486},
#   path='/Users/hongsupshin/ray_results/trainable_2024-07-21_16-09-43/trainable_8d0b1_00005_5_a=0.9715,b=0.4516_2024-07-21_16-09-43',
#   filesystem='local',
#   checkpoint=None
# )

# %%
results.get_dataframe()
# Out:
#       score   timestamp checkpoint_dir_name   done  training_iteration  \
# 0  0.813823  1721596188                None  False                  20
# 1  4.057555  1721596188                None  False                  20
# 2  4.070235  1721596188                None  False                  20
# 3  3.615182  1721596188                None  False                  20
# 4  0.719282  1721596188                None  False                  20
# 5  4.686165  1721596188                None  False                  20
# 6  0.614656  1721596188                None  False                  20
# 7  1.381706  1721596188                None  False                  20
# 8  3.362703  1721596191                None  False                  20
# 9  4.058900  1721596191                None  False                  20
#
#       trial_id                 date  time_this_iter_s  time_total_s    pid  \
# 0  8d0b1_00000  2024-07-21_16-09-48          0.000088      0.003706  13696
# 1  8d0b1_00001  2024-07-21_16-09-48          0.000130      0.002929  13697
# 2  8d0b1_00002  2024-07-21_16-09-48          0.000109      0.004182  13698
# 3  8d0b1_00003  2024-07-21_16-09-48          0.000297      0.002905  13699
# 4  8d0b1_00004  2024-07-21_16-09-48          0.000099      0.003188  13700
# 5  8d0b1_00005  2024-07-21_16-09-48          0.000168      0.003525  13701
# 6  8d0b1_00006  2024-07-21_16-09-48          0.000141      0.003677  13702
# 7  8d0b1_00007  2024-07-21_16-09-48          0.000124      0.003002  13703
# 8  8d0b1_00008  2024-07-21_16-09-51          0.000058      0.001449  13706
# 9  8d0b1_00009  2024-07-21_16-09-51          0.000060      0.001414  13707
#
#     hostname    node_ip  time_since_restore  iterations_since_restore  \
# 0  HSAir.lan  127.0.0.1            0.003706                        20
# 1  HSAir.lan  127.0.0.1            0.002929                        20
# 2  HSAir.lan  127.0.0.1            0.004182                        20
# 3  HSAir.lan  127.0.0.1            0.002905                        20
# 4  HSAir.lan  127.0.0.1            0.003188                        20
# 5  HSAir.lan  127.0.0.1            0.003525                        20
# 6  HSAir.lan  127.0.0.1            0.003677                        20
# 7  HSAir.lan  127.0.0.1            0.003002                        20
# 8  HSAir.lan  127.0.0.1            0.001449                        20
# 9  HSAir.lan  127.0.0.1            0.001414                        20
#
#    config/a  config/b       logdir
# 0  0.002728  0.801932  8d0b1_00000
# 1  0.832212  0.430026  8d0b1_00001
# 2  0.803056  0.569794  8d0b1_00002
# 3  0.728951  0.437756  8d0b1_00003
# 4  0.036474  0.560293  8d0b1_00004
# 5  0.971483  0.451571  8d0b1_00005
# 6  0.073087  0.296075  8d0b1_00006
# 7  0.164792  0.663394  8d0b1_00007
# 8  0.550588  0.962744  8d0b1_00008
# 9  0.747000  0.802802  8d0b1_00009

# %% [markdown]
# ## Prototype 3. lightgbm + ray +

# %% [markdown]
# How it would work for the LTR at work
# - group: synthetic creation
#     - bootstrap sample size
# - benchmark: whatever data I need
# - CV: try
# - hyperparameter tuning: try

# %%
config = {
        "objective": "binary",
        "metric": ["binary_error", "binary_logloss"],
        "verbose": -1,
        "boosting_type": tune.grid_search(["gbdt", "dart"]),
        "num_leaves": tune.randint(10, 1000),
        "learning_rate": tune.loguniform(1e-8, 1e-1),
    }
